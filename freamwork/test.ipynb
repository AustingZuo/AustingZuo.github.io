# %%
data_s = pd.read_csv('D:/我的文档/Desktop/化学计量学/2023.01/diff_zeo/2023.4.11【IZA】properties.csv')

data_s[data_s['ZEOTYPE']=='ANO'].reset_index(drop=True)['FDSi']
# Out:
# 0    16.5
# Name: FDSi, dtype: float64

# %%
import pandas as pd
li_ = ['ANO','CTH','EWF','EWT','ITN','JZO','PCS','PTO','PTY','SFV','SSO','STO','SVY','UOE']
data_s = pd.read_csv('D:/我的文档/Desktop/化学计量学/2023.01/diff_zeo/2023.4.11【IZA】properties.csv')
data = pd.read_csv('D:/我的文档/Desktop/sample.csv')
res = pd.DataFrame()
for zeo in li_:
    data = pd.read_csv('D:/我的文档/Desktop/sample.csv')
    data['ZEOTYPE'] = zeo
    data['FDSi'] = data_s[data_s['ZEOTYPE']==zeo].reset_index(drop=True)['FDSi'][0]
    data['Largest_Ring_sizes'] = data_s[data_s['ZEOTYPE']==zeo].reset_index(drop=True)['Largest_Ring_Sizes'][0]
    data['MDa'] = data_s[data_s['ZEOTYPE']==zeo].reset_index(drop=True)['MDa'][0]
    data['MDb'] = data_s[data_s['ZEOTYPE']==zeo].reset_index(drop=True)['MDb'][0]
    data['MDc'] = data_s[data_s['ZEOTYPE']==zeo].reset_index(drop=True)['MDc'][0]
    data['Mdi'] = data_s[data_s['ZEOTYPE']==zeo].reset_index(drop=True)['Mdi'][0]
    data['CD'] = data_s[data_s['ZEOTYPE']==zeo].reset_index(drop=True)['CD'][0]
    res = pd.concat([res, data])

# %%
res.to_csv('D:/我的文档/Desktop/res.csv', index=False)

# %%
list_ = ['ABW',
 'ACO',
 'AEN',
 'AET',
 'AFG',
 'AFR',
 'AFS',
 'AFT',
 'AFY',
 'AHT',
 'ANA',
 'ANO',
 'APC',
 'APD',
 'AST',
 'ASV',
 'ATO',
 'ATS',
 'ATT',
 'ATV',
 'AVE',
 'AVL',
 'AWO',
 'AWW',
 'BCT',
 'BEC',
 'BIK',
 'BOF',
 'BOG',
 'BOZ',
 'BPH',
 'BRE',
 'BSV',
 'CAN',
 'CAS',
 'CDO',
 'CFI',
 'CGF',
 'CGS',
 'CHI',
 'CLO',
 'CSV',
 'CTH',
 'CZP',
 'DAC',
 'DFO',
 'DFT',
 'DOH',
 'DON',
 'EAB',
 'EDI',
 'EEI',
 'EMT',
 'EON',
 'EPI',
 'ESV',
 'ETL',
 'ETR',
 'ETV',
 'EWF',
 'EWO',
 'EWS',
 'EWT',
 'EZT',
 'FAR',
 'FRA',
 'GIS',
 'GIU',
 'GME',
 'GON',
 'GOO',
 'HEU',
 'IFO',
 'IFR',
 'IFT',
 'IFU',
 'IFY',
 'IHW',
 'IMF',
 'IRN',
 'IRR',
 'IRY',
 'ISV',
 'ITG',
 'ITN',
 'ITR',
 'ITV',
 'ITW',
 'IWS',
 'IWV',
 'IWW',
 'JBW',
 'JNT',
 'JOZ',
 'JRY',
 'JSN',
 'JSR',
 'JST',
 'JSW',
 'JZO',
 'LAU',
 'LIO',
 'LIT',
 'LOS',
 'LOV',
 'LTF',
 'LTJ',
 'LTL',
 'LTN',
 'MAR',
 'MAZ',
 'MEI',
 'MEP',
 'MER',
 'MFS',
 'MON',
 'MOZ',
 'MRT',
 'MSE',
 'MSO',
 'MTF',
 'MTN',
 'MTT',
 'MVY',
 'MWF',
 'NAB',
 'NAT',
 'NES',
 'NON',
 'NPO',
 'NPT',
 'NSI',
 'OBW',
 'OFF',
 'OKO',
 'OSI',
 'OSO',
 'OWE',
 'PAR',
 'PAU',
 'PCR',
 'PCS',
 'PHI',
 'PON',
 'POR',
 'POS',
 'PSI',
 'PTO',
 'PTT',
 'PTY',
 'PUN',
 'PWN',
 'PWO',
 'PWW',
 'RON',
 'RRO',
 'RSN',
 'RTE',
 'RUT',
 'RWR',
 'RWY',
 'SAF',
 'SAO',
 'SAS',
 'SAT',
 'SBE',
 'SBN',
 'SBS',
 'SBT',
 'SEW',
 'SFE',
 'SFF',
 'SFG',
 'SFH',
 'SFN',
 'SFO',
 'SFS',
 'SFV',
 'SGT',
 'SIV',
 'SOD',
 'SOF',
 'SOR',
 'SOS',
 'SOV',
 'SSF',
 'SSO',
 'SSY',
 'STF',
 'STI',
 'STO',
 'STT',
 'STW',
 'SVR',
 'SVV',
 'SVY',
 'SWY',
 'SYT',
 'SZR',
 'TER',
 'THO',
 'TOL',
 'TSC',
 'TUN',
 'UEI',
 'UOE',
 'UOS',
 'UOV',
 'UOZ',
 'USI',
 'UTL',
 'UWY',
 'VET',
 'VFI',
 'VNI',
 'VSV',
 'WEI',
 'WEN',
 'YFI',
 'YUG',
 'ZON']

# %%
import pandas as pd
from jinja2 import Template


data1 = pd.read_csv('D:/我的文档/Desktop/res22.csv')
template = Template(open('test.html',encoding='utf-8').read())
li_ = ['ANO','CTH','EWF','EWT','ITN','JZO','PCS','PTO','PTY','SFV','SSO','STO','SVY','UOE']

for zeo_ in list_:
    try:
        data2 = data1[data1.ZEOTYPE == zeo_].sample(frac=0.004).reset_index(drop=True)
        for i in range(10):
            if data2.loc[i,"Conversion"] == 0:
                data2.loc[i,"Conversion"] = '≤ 98'
            else:
                data2.loc[i,"Conversion"] = '> 98'
        file_name = f'{data2.loc[0,"ZEOTYPE"]}.html'
        zeo=data2.loc[0,"ZEOTYPE"]
        fdsi=data2.loc[0,"FDSi"]
        lrs=data2.loc[0,"Largest_Ring_sizes"]
        mda=data2.loc[0,"MDa"]
        mdb=data2.loc[0,"MDb"]
        mdc=data2.loc[0,"MDc"]
        mdi=data2.loc[0,"Mdi"]
        cd=data2.loc[0,"CD"]
        mat1, mod1, as1, at1, cs1, rt1, whsv1, tos1, con1, st1, pe1 =  data2.loc[0, 'material'], data2.loc[0, 'Modification'], data2.loc[0, 'AS'],\
            data2.loc[0, 'A/T'], data2.loc[0, 'Crystal_size'], data2.loc[0, 'Reaction_temp'], data2.loc[0, 'WHSV'], data2.loc[0, 'TOS'],\
                data2.loc[0, 'Conversion'], data2.loc[0, 'Stotal'], data2.loc[0, 'P/E']
        mat2, mod2, as2, at2, cs2, rt2, whsv2, tos2, con2, st2, pe2 =  data2.loc[1, 'material'], data2.loc[1, 'Modification'], data2.loc[1, 'AS'],\
        data2.loc[1, 'A/T'], data2.loc[1, 'Crystal_size'], data2.loc[1, 'Reaction_temp'], data2.loc[1, 'WHSV'], data2.loc[1, 'TOS'],\
            data2.loc[1, 'Conversion'], data2.loc[1, 'Stotal'], data2.loc[1, 'P/E']
        mat3, mod3, as3, at3, cs3, rt3, whsv3, tos3, con3, st3, pe3 =  data2.loc[2, 'material'], data2.loc[2, 'Modification'], data2.loc[2, 'AS'],\
        data2.loc[2, 'A/T'], data2.loc[2, 'Crystal_size'], data2.loc[2, 'Reaction_temp'], data2.loc[2, 'WHSV'], data2.loc[2, 'TOS'],\
            data2.loc[2, 'Conversion'], data2.loc[2, 'Stotal'], data2.loc[2, 'P/E']
        mat4, mod4, as4, at4, cs4, rt4, whsv4, tos4, con4, st4, pe4 =  data2.loc[3, 'material'], data2.loc[3, 'Modification'], data2.loc[3, 'AS'],\
        data2.loc[3, 'A/T'], data2.loc[3, 'Crystal_size'], data2.loc[3, 'Reaction_temp'], data2.loc[3, 'WHSV'], data2.loc[3, 'TOS'],\
            data2.loc[3, 'Conversion'], data2.loc[3, 'Stotal'], data2.loc[3, 'P/E']
        mat5, mod5, as5, at5, cs5, rt5, whsv5, tos5, con5, st5, pe5 =  data2.loc[4, 'material'], data2.loc[4, 'Modification'], data2.loc[4, 'AS'],\
        data2.loc[4, 'A/T'], data2.loc[4, 'Crystal_size'], data2.loc[4, 'Reaction_temp'], data2.loc[4, 'WHSV'], data2.loc[4, 'TOS'],\
            data2.loc[4, 'Conversion'], data2.loc[4, 'Stotal'], data2.loc[4, 'P/E']
        mat6, mod6, as6, at6, cs6, rt6, whsv6, tos6, con6, st6, pe6 =  data2.loc[5, 'material'], data2.loc[5, 'Modification'], data2.loc[5, 'AS'],\
        data2.loc[5, 'A/T'], data2.loc[5, 'Crystal_size'], data2.loc[5, 'Reaction_temp'], data2.loc[5, 'WHSV'], data2.loc[5, 'TOS'],\
            data2.loc[5, 'Conversion'], data2.loc[5, 'Stotal'], data2.loc[5, 'P/E']
        mat7, mod7, as7, at7, cs7, rt7, whsv7, tos7, con7, st7, pe7 =  data2.loc[6, 'material'], data2.loc[6, 'Modification'], data2.loc[6, 'AS'],\
        data2.loc[6, 'A/T'], data2.loc[6, 'Crystal_size'], data2.loc[6, 'Reaction_temp'], data2.loc[6, 'WHSV'], data2.loc[6, 'TOS'],\
            data2.loc[6, 'Conversion'], data2.loc[6, 'Stotal'], data2.loc[6, 'P/E']
        mat8, mod8, as8, at8, cs8, rt8, whsv8, tos8, con8, st8, pe8 =  data2.loc[7, 'material'], data2.loc[7, 'Modification'], data2.loc[7, 'AS'],\
        data2.loc[7, 'A/T'], data2.loc[7, 'Crystal_size'], data2.loc[7, 'Reaction_temp'], data2.loc[7, 'WHSV'], data2.loc[7, 'TOS'],\
            data2.loc[7, 'Conversion'], data2.loc[7, 'Stotal'], data2.loc[7, 'P/E']
        mat9, mod9, as9, at9, cs9, rt9, whsv9, tos9, con9, st9, pe9 =  data2.loc[8, 'material'], data2.loc[8, 'Modification'], data2.loc[8, 'AS'],\
        data2.loc[8, 'A/T'], data2.loc[8, 'Crystal_size'], data2.loc[8, 'Reaction_temp'], data2.loc[8, 'WHSV'], data2.loc[8, 'TOS'],\
            data2.loc[8, 'Conversion'], data2.loc[8, 'Stotal'], data2.loc[8, 'P/E']
        mat10, mod10, as10, at10, cs10, rt10, whsv10, tos10, con10, st10, pe10 =  data2.loc[9, 'material'], data2.loc[9, 'Modification'], data2.loc[9, 'AS'],\
        data2.loc[9, 'A/T'], data2.loc[9, 'Crystal_size'], data2.loc[9, 'Reaction_temp'], data2.loc[9, 'WHSV'], data2.loc[9, 'TOS'],\
            data2.loc[9, 'Conversion'], data2.loc[9, 'Stotal'], data2.loc[9, 'P/E']

        html = template.render(
            zeo = zeo, fdsi = fdsi, lrs = lrs, mda = mda, mdb = mdb, mdc = mdc, mdi = mdi,cd = cd,
            mat1 = mat1, mat2 = mat2, mat3 = mat3, mat4 = mat4, mat5 = mat5, mat6 = mat6, mat7 = mat7, mat8 = mat8, mat9 = mat9, mat10 = mat10,
            mod1 = mod1, mod2 = mod2, mod3 = mod3, mod4 = mod4, mod5 = mod5, mod6 = mod6, mod7 = mod7, mod8 = mod8, mod9 = mod9, mod10 = mod10,
            as1 = as1, as2 = as2, as3 = as3, as4 = as4, as5 = as5, as6=as6, as7=as7, as8=as8, as9=as9, as10=as10,
            at1=at1, at2=at2, at3=at3, at4=at4,at5=at5,at6=at6,at7=at7,at8=at8,at9=at9,at10=at10,
            cs1=cs1, cs2=cs2, cs3=cs3,cs4=cs4,cs5=cs5,cs6=cs6,cs7=cs7,cs8=cs8,cs9=cs9,cs10=cs10,
            rt1=rt1, rt2=rt2, rt3=rt3,rt4=rt4,rt5=rt5,rt6=rt6,rt7=rt7,rt8=rt8,rt9=rt9,rt10=rt10,
            whsv1=whsv1,whsv2=whsv2,whsv3=whsv3,whsv4=whsv4,whsv5=whsv5,whsv6=whsv6,whsv7=whsv7,whsv8=whsv8,whsv9=whsv9,whsv10=whsv10,
            tos1=tos1,tos2=tos2,tos3=tos3,tos4=tos4,tos5=tos5,tos6=tos6,tos7=tos7,tos8=tos8,tos9=tos9,tos10=tos10,
            con1=con1,con2=con2,con3=con3,con4=con4,con5=con5,con6=con6,con7=con7,con8=con8,con9=con9,con10=con10,
            st1=st1,st2=st2,st3=st3,st4=st4,st5=st5,st6=st6,st7=st7,st8=st8,st9=st9,st10=st10,
            pe1=pe1,pe2=pe2,pe3=pe3,pe4=pe4,pe5=pe5,pe6=pe6,pe7=pe7,pe8=pe8,pe9=pe9,pe10=pe10
        )
            # 将HTML写入文件
        with open(file_name, 'w',encoding='utf-8') as f:
            f.write(html)
    except:
        print(zeo_)
# Out:
# ANO
# CTH
# EWF
# EWT
# ITN
# JZO
# PCS
# PTO
# PTY
# SFV
# SSO
# STO
# SVY
# UOE

# %%
li_ = ['ANO','CTH','EWF','EWT','ITN','JZO','PCS','PTO','PTY','SFV','SSO','STO','SVY','UOE']
datas = ['AEI', 'AEL', 'AFI', 'AFN', 'AFO', 'AFV', 'AFX', 'ATN', 'AVL', 'BEA', 'CHA', 'CON', 'DDR', 'ERI', 'EUO', 'FAU',
'FER', 'IFW', 'ITE', 'ITH', 'ITT', 'IWR', 'KFI', 'LEV', 'LTA', 'MEL', 'MFI', 'MOR', 'MRE', 'MTW', 'MWW', 'RHO', 'RTH', 'SAV', 'SFW', 'TON', 'UFI']

# %%
import pandas as pd
from jinja2 import Template

data1 = pd.read_csv('D:/我的文档/Desktop/化学计量学/2023.01/diff_zeo/2023.4.11【IZA】properties.csv')
template = Template(open('test2.html',encoding='utf-8').read())

for zeo_ in datas:
    data2 = data1[data1.ZEOTYPE == zeo_].reset_index(drop=True)
    file_name = f'{data2.loc[0,"ZEOTYPE"]}.html'
    zeo=data2.loc[0,"ZEOTYPE"]
    fdsi=data2.loc[0,"FDSi"]
    lrs=data2.loc[0,"Largest_Ring_Sizes"]
    mda=data2.loc[0,"MDa"]
    mdb=data2.loc[0,"MDb"]
    mdc=data2.loc[0,"MDc"]
    mdi=data2.loc[0,"Mdi"]
    cd=data2.loc[0,"CD"]

    html = template.render(
        zeo = zeo, fdsi = fdsi, lrs = lrs, mda = mda, mdb = mdb, mdc = mdc, mdi = mdi,cd = cd)
        # 将HTML写入文件
    with open(file_name, 'w',encoding='utf-8') as f:
        f.write(html)

# %%
data1
# Out:
# 'D:/我的文档/Desktop/化学计量学/2023.01/diff_zeo/2023.4.11【IZA】properties.csv'
